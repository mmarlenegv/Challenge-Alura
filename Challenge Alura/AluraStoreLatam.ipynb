# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %%
##Ingreso total por cada tienda
Ingreso_total_tienda1 = sum(tienda['Precio'])
Ingreso_total_tienda2 = sum(tienda2['Precio'])
Ingreso_total_tienda3 = sum(tienda3['Precio'])
Ingreso_total_tienda4 = sum(tienda4['Precio'])
print(f'Ingreso total de la tienda 1 es : {Ingreso_total_tienda1}')
print(f'Ingreso total de la tienda 2 es : {Ingreso_total_tienda2}')
print(f'Ingreso total de la tienda 3 es : {Ingreso_total_tienda3}')
print(f'Ingreso total de la tienda 4 es : {Ingreso_total_tienda4}')
# Out:
# Ingreso total de la tienda 1 es : 1150880400.0
# Ingreso total de la tienda 2 es : 1116343500.0
# Ingreso total de la tienda 3 es : 1098019600.0
# Ingreso total de la tienda 4 es : 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_por_categoria_tienda1 = tienda['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda2 = tienda2['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda3 = tienda3['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda4 = tienda4['Categoría del Producto'].value_counts()

# %%
print(f'La cantidad de producto por categoría de la tienda 1: \n{ventas_por_categoria_tienda1}')
# Out:
# La cantidad de producto por categoría de la tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
print(f'La cantidad de producto por categoría de la tienda 2: \n{ventas_por_categoria_tienda2}')
# Out:
# La cantidad de producto por categoría de la tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
print(f'La cantidad de producto por categoría de la tienda 3: \n{ventas_por_categoria_tienda3}')
# Out:
# La cantidad de producto por categoría de la tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
print(f'La cantidad de producto por categoría de la tienda 4: \n{ventas_por_categoria_tienda4}')
# Out:
# La cantidad de producto por categoría de la tienda 4:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
##Ventas agrupadas por Categoría
venta1 = tienda.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio',ascending=False)
venta2 = tienda2.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio',ascending=False)
venta3 = tienda3.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio',ascending=False)
venta4 = tienda4.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio',ascending=False)

# %%
print(f'Las ventas agrupadas por categoría de la tienda 1: \n{venta1}')
# Out:
# Las ventas agrupadas por categoría de la tienda 1:
#                               Precio
# Categoría del Producto
# Electrónicos             429493500.0
# Electrodomésticos        363685200.0
# Muebles                  187633700.0
# Instrumentos musicales    91299000.0
# Deportes y diversión      39290000.0
# Juguetes                  17995700.0
# Artículos para el hogar   12698400.0
# Libros                     8784900.0

# %%
print(f'Las ventas agrupadas por categoría de la tienda 2: \n{venta2}')
# Out:
# Las ventas agrupadas por categoría de la tienda 2:
#                               Precio
# Categoría del Producto
# Electrónicos             410831100.0
# Electrodomésticos        348567800.0
# Muebles                  176426300.0
# Instrumentos musicales   104990300.0
# Deportes y diversión      34744500.0
# Juguetes                  15945400.0
# Artículos para el hogar   14746900.0
# Libros                    10091200.0

# %%
print(f'Las ventas agrupadas por categoría de la tienda 3: \n{venta3}')
# Out:
# Las ventas agrupadas por categoría de la tienda 3:
#                               Precio
# Categoría del Producto
# Electrónicos             410775800.0
# Electrodomésticos        329237900.0
# Muebles                  201072100.0
# Instrumentos musicales    77380900.0
# Deportes y diversión      35593100.0
# Juguetes                  19401100.0
# Artículos para el hogar   15060000.0
# Libros                     9498700.0

# %%
print(f'Las ventas agrupadas por categoría de la tienda 4: \n{venta4}')
# Out:
# Las ventas agrupadas por categoría de la tienda 4:
#                               Precio
# Categoría del Producto
# Electrónicos             409476100.0
# Electrodomésticos        283260200.0
# Muebles                  192528900.0
# Instrumentos musicales    75102400.0
# Deportes y diversión      33350100.0
# Juguetes                  20262200.0
# Artículos para el hogar   15074500.0
# Libros                     9321300.0

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
promedio_calificacion_tienda1 = tienda['Calificación'].mean().round(2)
promedio_calificacion_tienda2 = tienda2['Calificación'].mean().round(2)
promedio_calificacion_tienda3 = tienda3['Calificación'].mean().round(2)
promedio_calificacion_tienda4 = tienda4['Calificación'].mean().round(2)

# %%
print(f' El promedio de calificación de la tienda 1 es: {promedio_calificacion_tienda1}')
print(f' El promedio de calificación de la tienda 2 es: {promedio_calificacion_tienda2}')
print(f' El promedio de calificación de la tienda 3 es: {promedio_calificacion_tienda3}')
print(f' El promedio de calificación de la tienda 4 es: {promedio_calificacion_tienda4}')
# Out:
#  El promedio de calificación de la tienda 1 es: 3.98
#  El promedio de calificación de la tienda 2 es: 4.04
#  El promedio de calificación de la tienda 3 es: 4.05
#  El promedio de calificación de la tienda 4 es: 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
venta_producto_tienda1 = tienda['Producto'].value_counts()
venta_producto_tienda2 = tienda2['Producto'].value_counts()
venta_producto_tienda3 = tienda3['Producto'].value_counts()
venta_producto_tienda4 = tienda4['Producto'].value_counts()

# %%
print(f'Se muestra los productos más vendidos de forma ascendente:\n{venta_producto_tienda1}')
# Out:
# Se muestra los productos más vendidos de forma ascendente:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# Smart TV                       44
# Cama king                      44
# Cubo mágico 8x8                44
# Mesa de centro                 44
# Set de ollas                   43
# Smartwatch                     43
# Juego de mesa                  43
# Balón de voleibol              42
# Dashboards con Power BI        42
# Tablet ABXY                    42
# Sillón                         41
# Iniciando en programación      41
# Set de vasos                   41
# Asistente virtual              40
# Muñeca bebé                    40
# Mesa de comedor                40
# Dinosaurio Rex                 40
# Cuerda para saltar             40
# Mochila                        39
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %%
print(f'Se muestra los productos más vendidos de forma ascendente:\n{venta_producto_tienda2}')
# Out:
# Se muestra los productos más vendidos de forma ascendente:
# Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Guitarra acústica              58
# Pandereta                      58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Silla de oficina               49
# Refrigerador                   49
# Muñeca bebé                    48
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Cama box                       47
# Vaso térmico                   47
# Modelado predictivo            46
# Balón de voleibol              46
# Set de vasos                   46
# Lavavajillas                   46
# Kit de bancas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# Cubo mágico 8x8                45
# Ajedrez de madera              45
# Mesa de centro                 45
# TV LED UHD 4K                  45
# Tablet ABXY                    44
# Smartwatch                     44
# Mesa de noche                  44
# Olla de presión                44
# Auriculares con micrófono      44
# Sofá reclinable                44
# Dashboards con Power BI        43
# Ciencia de datos con Python    43
# Balón de baloncesto            42
# Estufa                         42
# Dinosaurio Rex                 42
# Celular ABXY                   41
# Smart TV                       40
# Cubertería                     39
# Asistente virtual              38
# Auriculares                    37
# Sillón                         35
# Mesa de comedor                34
# Impresora                      34
# Juego de mesa                  32
# Name: count, dtype: int64

# %%
print(f'Se muestra los productos más vendidos de forma ascendente:\n{venta_producto_tienda3}')
# Out:
# Se muestra los productos más vendidos de forma ascendente:
# Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Estufa                         53
# Cuerda para saltar             53
# Modelado predictivo            53
# Carrito de control remoto      52
# Lavavajillas                   52
# Bicicleta                      52
# Juego de mesa                  52
# Pandereta                      51
# Impresora                      50
# Refrigerador                   50
# Balón de baloncesto            50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Sillón                         47
# Guitarra acústica              47
# Olla de presión                47
# Ajedrez de madera              47
# Ciencia de datos con Python    46
# Iphone 15                      46
# Dinosaurio Rex                 46
# Silla de oficina               46
# Smartwatch                     46
# Cama box                       46
# Iniciando en programación      46
# Secadora de ropa               45
# Sofá reclinable                45
# Celular ABXY                   44
# Cubo mágico 8x8                44
# Auriculares                    43
# TV LED UHD 4K                  42
# Mesa de centro                 42
# Lavadora de ropa               42
# Batería                        41
# Dashboards con Power BI        40
# Cubertería                     39
# Muñeca bebé                    39
# Auriculares con micrófono      39
# Asistente virtual              39
# Vaso térmico                   38
# Guitarra eléctrica             38
# Set de vasos                   36
# Mochila                        36
# Microondas                     36
# Bloques de construcción        35
# Name: count, dtype: int64

# %%
print(f'Se muestra los productos más vendidos de forma ascendente:\n{venta_producto_tienda4}')
# Out:
# Se muestra los productos más vendidos de forma ascendente:
# Producto
# Cama box                       62
# Cubertería                     59
# Dashboards con Power BI        56
# Cama king                      56
# Carrito de control remoto      55
# Mesa de comedor                55
# Mesa de noche                  55
# Smart TV                       54
# Bloques de construcción        54
# Pandereta                      52
# Impresora                      50
# Modelado predictivo            50
# Asistente virtual              50
# Set de ollas                   50
# Balón de baloncesto            50
# Vaso térmico                   48
# Iphone 15                      48
# Muñeca bebé                    48
# Batería                        48
# Balón de voleibol              48
# Juego de mesa                  48
# Microondas                     48
# Estufa                         47
# Cubo mágico 8x8                47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# Set de vasos                   46
# Tablet ABXY                    45
# Sillón                         45
# Bicicleta                      45
# Mesa de centro                 44
# Auriculares                    44
# Lavavajillas                   43
# Cuerda para saltar             43
# Iniciando en programación      43
# Mochila                        43
# Auriculares con micrófono      42
# Kit de bancas                  42
# TV LED UHD 4K                  40
# Secadora de ropa               40
# Silla de oficina               40
# Celular ABXY                   39
# Ajedrez de madera              39
# Smartwatch                     39
# Lavadora de ropa               38
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %%
producto_menos_vendidos_tienda1 = tienda['Producto'].value_counts()
producto_menos_vendidos_tienda1
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# Smart TV                       44
# Cama king                      44
# Cubo mágico 8x8                44
# Mesa de centro                 44
# Set de ollas                   43
# Smartwatch                     43
# Juego de mesa                  43
# Balón de voleibol              42
# Dashboards con Power BI        42
# Tablet ABXY                    42
# Sillón                         41
# Iniciando en programación      41
# Set de vasos                   41
# Asistente virtual              40
# Muñeca bebé                    40
# Mesa de comedor                40
# Dinosaurio Rex                 40
# Cuerda para saltar             40
# Mochila                        39
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %%
producto_menos_vendidos_tienda2 = tienda2['Producto'].value_counts()
producto_menos_vendidos_tienda2
# Out:
# Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Guitarra acústica              58
# Pandereta                      58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Silla de oficina               49
# Refrigerador                   49
# Muñeca bebé                    48
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Cama box                       47
# Vaso térmico                   47
# Modelado predictivo            46
# Balón de voleibol              46
# Set de vasos                   46
# Lavavajillas                   46
# Kit de bancas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# Cubo mágico 8x8                45
# Ajedrez de madera              45
# Mesa de centro                 45
# TV LED UHD 4K                  45
# Tablet ABXY                    44
# Smartwatch                     44
# Mesa de noche                  44
# Olla de presión                44
# Auriculares con micrófono      44
# Sofá reclinable                44
# Dashboards con Power BI        43
# Ciencia de datos con Python    43
# Balón de baloncesto            42
# Estufa                         42
# Dinosaurio Rex                 42
# Celular ABXY                   41
# Smart TV                       40
# Cubertería                     39
# Asistente virtual              38
# Auriculares                    37
# Sillón                         35
# Mesa de comedor                34
# Impresora                      34
# Juego de mesa                  32
# Name: count, dtype: int64

# %%
producto_menos_vendidos_tienda3 = tienda3['Producto'].value_counts()
producto_menos_vendidos_tienda3
# Out:
# Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Estufa                         53
# Cuerda para saltar             53
# Modelado predictivo            53
# Carrito de control remoto      52
# Lavavajillas                   52
# Bicicleta                      52
# Juego de mesa                  52
# Pandereta                      51
# Impresora                      50
# Refrigerador                   50
# Balón de baloncesto            50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Sillón                         47
# Guitarra acústica              47
# Olla de presión                47
# Ajedrez de madera              47
# Ciencia de datos con Python    46
# Iphone 15                      46
# Dinosaurio Rex                 46
# Silla de oficina               46
# Smartwatch                     46
# Cama box                       46
# Iniciando en programación      46
# Secadora de ropa               45
# Sofá reclinable                45
# Celular ABXY                   44
# Cubo mágico 8x8                44
# Auriculares                    43
# TV LED UHD 4K                  42
# Mesa de centro                 42
# Lavadora de ropa               42
# Batería                        41
# Dashboards con Power BI        40
# Cubertería                     39
# Muñeca bebé                    39
# Auriculares con micrófono      39
# Asistente virtual              39
# Vaso térmico                   38
# Guitarra eléctrica             38
# Set de vasos                   36
# Mochila                        36
# Microondas                     36
# Bloques de construcción        35
# Name: count, dtype: int64

# %%
producto_menos_vendidos_tienda4 = tienda4['Producto'].value_counts()
producto_menos_vendidos_tienda4
# Out:
# Producto
# Cama box                       62
# Cubertería                     59
# Dashboards con Power BI        56
# Cama king                      56
# Carrito de control remoto      55
# Mesa de comedor                55
# Mesa de noche                  55
# Smart TV                       54
# Bloques de construcción        54
# Pandereta                      52
# Impresora                      50
# Modelado predictivo            50
# Asistente virtual              50
# Set de ollas                   50
# Balón de baloncesto            50
# Vaso térmico                   48
# Iphone 15                      48
# Muñeca bebé                    48
# Batería                        48
# Balón de voleibol              48
# Juego de mesa                  48
# Microondas                     48
# Estufa                         47
# Cubo mágico 8x8                47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# Set de vasos                   46
# Tablet ABXY                    45
# Sillón                         45
# Bicicleta                      45
# Mesa de centro                 44
# Auriculares                    44
# Lavavajillas                   43
# Cuerda para saltar             43
# Iniciando en programación      43
# Mochila                        43
# Auriculares con micrófono      42
# Kit de bancas                  42
# TV LED UHD 4K                  40
# Secadora de ropa               40
# Silla de oficina               40
# Celular ABXY                   39
# Ajedrez de madera              39
# Smartwatch                     39
# Lavadora de ropa               38
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
promedio_envio_tienda1 = tienda['Costo de envío'].mean()
promedio_envio_tienda2 = tienda2['Costo de envío'].mean()
promedio_envio_tienda3 = tienda3['Costo de envío'].mean()
promedio_envio_tienda4 = tienda4['Costo de envío'].mean()

# %%
print(f'El promedio de envío de la tienda 1 es: {promedio_envio_tienda1}')
print(f'El promedio de envío de la tienda 2 es: {promedio_envio_tienda2}')
print(f'El promedio de envío de la tienda 3 es: {promedio_envio_tienda3}')
print(f'El promedio de envío de la tienda 4 es: {promedio_envio_tienda4}')
# Out:
# El promedio de envío de la tienda 1 es: 26018.60958033065
# El promedio de envío de la tienda 2 es: 25216.235693090293
# El promedio de envío de la tienda 3 es: 24805.680373039424
# El promedio de envío de la tienda 4 es: 23459.457167090754

# %% [markdown]
# ###Gráficos

# %%
import math
import matplotlib.pyplot as plt

ingresos = {
    "Tienda 1": Ingreso_total_tienda1,
    "Tienda 2": Ingreso_total_tienda2,
    "Tienda 3": Ingreso_total_tienda3,
    "Tienda 4": Ingreso_total_tienda4,
}

plt.bar(ingresos.keys(), ingresos.values(), color=["blue", "orange", "green", "red"])
plt.title("Ingresos totales por tienda")
plt.xlabel("Tienda")
plt.ylabel("Ingreso total")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.barh(ventas_por_categoria_tienda1.index, ventas_por_categoria_tienda1.values, label="Tienda 1")
plt.barh(ventas_por_categoria_tienda2.index, ventas_por_categoria_tienda2.values, label="Tienda 2")
plt.barh(ventas_por_categoria_tienda3.index, ventas_por_categoria_tienda3.values, label="Tienda 3")
plt.barh(ventas_por_categoria_tienda4.index, ventas_por_categoria_tienda4.values, label="Tienda 4")

plt.legend()
plt.title("Ventas por categoría (todas las tiendas)")
plt.show()

# %%
import matplotlib.pyplot as plt

# Aplicamos top 10 a cada tienda
top10_1 = venta_producto_tienda1.head(10)
top10_2 = venta_producto_tienda2.head(10)
top10_3 = venta_producto_tienda3.head(10)
top10_4 = venta_producto_tienda4.head(10)

fig, axs = plt.subplots(2, 2, figsize=(12, 8))

axs[0,0].barh(top10_1.index, top10_1.values)
axs[0,0].set_title("Tienda 1 - Top 10 productos")

axs[0,1].barh(top10_2.index, top10_2.values)
axs[0,1].set_title("Tienda 2 - Top 10 productos")

axs[1,0].barh(top10_3.index, top10_3.values)
axs[1,0].set_title("Tienda 3 - Top 10 productos")

axs[1,1].barh(top10_4.index, top10_4.values)
axs[1,1].set_title("Tienda 4 - Top 10 productos")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Informe Final**

# %% [markdown]
# ####**Análisis Comparativo de Tiendas**

# %% [markdown]
# En el presente informe se resume los hallazgos clave sobre ingresos, demanda por categorías y productos, así como las calificaciones de clientes y coste de envío promedio.
#
# **Justificación**
#
# La selección de esta tienda se fundamenta en su desempeño sólido y equilibrado dentro del análisis comparativo.
#
# Presenta el segundo mayor nivel de ingresos, respaldado por una alta rotación en categorías estratégicas, lo que evidencia su dinamismo comercial. Asimismo, posee una calificación de satisfacción del cliente de 4.04, muy cercana al valor más alto del conjunto, lo cual refleja una experiencia de compra positiva y consistente.
# A nivel operativo, destaca también por registrar el menor coste de envío promedio (22,512.24), un factor que contribuye a mejorar la eficiencia y el margen de rentabilidad.
#
# En contraste, aunque la Tienda 1 lidera en facturación, muestra la calificación más baja (3.98), mientras que la Tienda 3, pese a presentar buena satisfacción, incurre en el mayor coste de envío.
#
# Estos elementos justifican la elección de la tienda evaluada como la alternativa con mejor equilibrio entre ingresos, satisfacción del cliente y eficiencia operativa.
#
# Al final del informe se propone una recomendación basada en el balance entre facturación, rotación, satisfacción y eficiencia logística.

# %% [markdown]
# #####**Análisis de facturación**
#
# ####**Ingresos totales por tienda**
#
# Ingreso total
#
#   Tienda 1: 1.150.880.400,00
#
#   Tienda 2: 1.116.434.500,00
#
#   Tienda 3: 1.098.019.600,00
#
#   Tienda 4: 1.038.375.700,00
#
# Según lo analizado en **Ingresos totales por tienda** se muestra que el ingreso total proviene de la tienda 1 y el menor ingreso de la tienda 4
#
# Dentro de las ventas por Categoría se observa que la categoría más vendida en todas las tiendas son: **Muebles.**
#
# **En Ventas agrupadas por categoría (ranking por ingresos)**
#
# Según los totales por categoría (suma de Precio), el ranking observado es:
#
# Tienda 1: Electrónicos, Electrodomésticos, Muebles, Instrumentos musicales, Juguetes, Artículos para el hogar, Libros, Deportes y diversión
#
# Tienda 2: Electrónicos, Electrodomésticos, Muebles, Instrumentos musicales, Deportes y diversión, Juguetes, Joyería, Libros
#
# Tienda 3: Electrónicos, Electrodomésticos, Muebles, Instrumentos musicales, Deportes y diversión, Juguetes, Artículos para el hogar, Libros
#
# Tienda 4: Electrónicos, Electrodomésticos, Muebles, Instrumentos musicales, Deportes y diversión, Juguetes, Artículos para el hogar, Libros
#
# Nota: En todas las tiendas destacan Electrónicos y Electrodomésticos como motores de ingresos; Muebles ocupa el tercer lugar.
#
# De igual forma, en **Calificación promedio por tienda** los resultados analizados son los siguientes:
# Promedios (escala 1–5)
#
#
#   Tienda 3: 4,05
#
#   Tienda 2: 4,04
#
#   Tienda 4: 4,00
#
#   Tienda 1: 3,98
#
# **La tienda 3 obtuvo la mejor calificación promedio**
#
# Dentro de **Productos más y menos vendidos**
#
# Criterio: se utilizaron value_counts() por producto para identificar Top 10 y Bottom 10 en cada tienda. Dado el volumen de ítems, se adjuntan en los gráficos/tablas del cuaderno.
#
# En general, los artículos de electrónica y línea blanca figuran entre los más vendidos; en el bottom aparecen artículos de baja denanda o rotación baja.

# %%
# @title
import matplotlib.pyplot as plt

# Top 10
top10_1 = venta_producto_tienda1.head(10)
top10_2 = venta_producto_tienda2.head(10)
top10_3 = venta_producto_tienda3.head(10)
top10_4 = venta_producto_tienda4.head(10)

# Bottom 10
bottom10_1 = venta_producto_tienda1.tail(10)
bottom10_2 = venta_producto_tienda2.tail(10)
bottom10_3 = venta_producto_tienda3.tail(10)
bottom10_4 = venta_producto_tienda4.tail(10)

# --- Gráficos Top ---
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].barh(top10_1.index[::-1], top10_1.values[::-1]); axs[0,0].set_title("Tienda 1 - Top 10")
axs[0,1].barh(top10_2.index[::-1], top10_2.values[::-1]); axs[0,1].set_title("Tienda 2 - Top 10")
axs[1,0].barh(top10_3.index[::-1], top10_3.values[::-1]); axs[1,0].set_title("Tienda 3 - Top 10")
axs[1,1].barh(top10_4.index[::-1], top10_4.values[::-1]); axs[1,1].set_title("Tienda 4 - Top 10")
plt.tight_layout(); plt.show()

# --- Gráficos Bottom ---
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs[0,0].barh(bottom10_1.index[::-1], bottom10_1.values[::-1]); axs[0,0].set_title("Tienda 1 - Bottom 10")
axs[0,1].barh(bottom10_2.index[::-1], bottom10_2.values[::-1]); axs[0,1].set_title("Tienda 2 - Bottom 10")
axs[1,0].barh(bottom10_3.index[::-1], bottom10_3.values[::-1]); axs[1,0].set_title("Tienda 3 - Bottom 10")
axs[1,1].barh(bottom10_4.index[::-1], bottom10_4.values[::-1]); axs[1,1].set_title("Tienda 4 - Bottom 10")
plt.tight_layout(); plt.show()

# %% [markdown]
# ####**Envío promedio por tienda**
#
# Coste de envío promedio
#
#   Tienda 1: 26.018,66
#
#   Tienda 2: 22.512,24
#
#   Tienda 3: 40.885,61
#
#   Tienda 4: 23.459,46
#
# Dentro del análisis en **Envío promedio por tienda**, se evidencia que el Coste de envío promedio lo lidera la Tienda 3: 40.885,61.
#
# *Observación: Tienda 2 presenta el menor coste promedio de envío; Tienda 3 es la más costosa.*
#
# **Recomendación final**
#
# Se debe Priorizar la **Tienda 2** para la venta de productos.
#
# **Conclusiones**
#
# La evaluación comparativa entre las tiendas muestra que la unidad seleccionada destaca por un desempeño equilibrado y competitivo. En primer lugar, presenta el segundo mayor nivel de ingresos, acompañado de una alta rotación en categorías clave, lo que confirma su relevancia comercial dentro del portafolio. Además, alcanza una calificación de satisfacción del cliente de 4.04, un valor cercano al más alto registrado, lo que evidencia una experiencia de compra consistentemente positiva.
# Por otro lado, esta tienda reporta el menor coste de envío promedio (S/ 22,512.24), lo cual contribuye a mejorar el margen operativo y reforzar su competitividad frente a las demás unidades. Finalmente, aunque la Tienda 1 lidera en facturación, muestra la calificación más baja (3.98), y la Tienda 3, pese a su buena valoración, posee el coste de envío más elevado, lo que reduce su eficiencia comparativa. Estos factores en conjunto respaldan la elección de la tienda analizada como la alternativa con mejor equilibrio entre ingresos, satisfacción y eficiencia operativa.
